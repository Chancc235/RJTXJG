# %%
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties
font_path = '/System/Library/Fonts/PingFang.ttc'
font_prop = FontProperties(fname=font_path)
plt.rcParams['font.sans-serif'] = ['Heiti TC']

# %%
# Recreate a UML-style package diagram using matplotlib to visually represent package relationships

plt.figure(figsize=(12, 10))

# Draw rectangles for each main package and sub-package
# Using annotation boxes to simulate package-style layout

# Frontend package
plt.gca().add_patch(plt.Rectangle((0.1, 0.7), 0.3, 0.2, fill=True, color='lightblue', edgecolor='black'))
plt.text(0.12, 0.88, "frontend", fontsize=12, fontweight='bold')

# Dispatcher and Context Listener in frontend
plt.gca().add_patch(plt.Rectangle((0.12, 0.75), 0.12, 0.05, fill=True, color='white', edgecolor='black'))
plt.text(0.125, 0.76, "Dispatcher", fontsize=10)
plt.gca().add_patch(plt.Rectangle((0.24, 0.75), 0.12, 0.05, fill=True, color='white', edgecolor='black'))
plt.text(0.245, 0.76, "Context Listener", fontsize=10)

# Backend package
plt.gca().add_patch(plt.Rectangle((0.5, 0.5), 0.35, 0.4, fill=True, color='lightgreen', edgecolor='black'))
plt.text(0.52, 0.88, "backend", fontsize=12, fontweight='bold')

# YOLOv8 Detector, BeanManager, and ResultStore in backend
plt.gca().add_patch(plt.Rectangle((0.52, 0.75), 0.12, 0.05, fill=True, color='white', edgecolor='black'))
plt.text(0.525, 0.76, "YOLOv8 Detector", fontsize=10)
plt.gca().add_patch(plt.Rectangle((0.66, 0.75), 0.12, 0.05, fill=True, color='white', edgecolor='black'))
plt.text(0.665, 0.76, "BeanManager", fontsize=10)
plt.gca().add_patch(plt.Rectangle((0.52, 0.6), 0.12, 0.05, fill=True, color='white', edgecolor='black'))
plt.text(0.525, 0.61, "ResultStore", fontsize=10)

# Observer and Account inheritance in backend
plt.gca().add_patch(plt.Rectangle((0.68, 0.6), 0.15, 0.15, fill=True, color='white', edgecolor='black'))
plt.text(0.685, 0.72, "Observer", fontsize=10, fontweight='bold')
plt.text(0.685, 0.66, "Account", fontsize=10)

# Account subclasses
plt.gca().add_patch(plt.Rectangle((0.68, 0.55), 0.06, 0.04, fill=True, color='white', edgecolor='black'))
plt.text(0.685, 0.56, "CheckingAccount", fontsize=9)
plt.gca().add_patch(plt.Rectangle((0.75, 0.55), 0.06, 0.04, fill=True, color='white', edgecolor='black'))
plt.text(0.755, 0.56, "SavingsAccount", fontsize=9)

# AdminAccountView implementing Observer
plt.gca().add_patch(plt.Rectangle((0.68, 0.45), 0.15, 0.05, fill=True, color='white', edgecolor='black'))
plt.text(0.685, 0.46, "AdminAccountView", fontsize=10)

# Database package
plt.gca().add_patch(plt.Rectangle((0.1, 0.2), 0.3, 0.15, fill=True, color='lightcoral', edgecolor='black'))
plt.text(0.12, 0.32, "database", fontsize=12, fontweight='bold')
plt.gca().add_patch(plt.Rectangle((0.12, 0.23), 0.26, 0.05, fill=True, color='white', edgecolor='black'))
plt.text(0.125, 0.24, "ResultStore (Data Table)", fontsize=10)

# Add arrows for relationships
# Dispatcher -> BeanManager
plt.arrow(0.25, 0.75, 0.25, -0.1, head_width=0.02, head_length=0.02, fc='black', ec='black')
# BeanManager -> YOLOv8 Detector
plt.arrow(0.66, 0.7, -0.1, 0, head_width=0.02, head_length=0.02, fc='black', ec='black')
# YOLOv8 Detector -> ResultStore
plt.arrow(0.575, 0.68, 0.0, -0.05, head_width=0.02, head_length=0.02, fc='black', ec='black')
# ResultStore -> Database
plt.arrow(0.52, 0.62, -0.25, -0.3, head_width=0.02, head_length=0.02, fc='black', ec='black')
# Account -> Observer
plt.arrow(0.725, 0.66, -0.04, 0.0, head_width=0.02, head_length=0.02, fc='black', ec='black')
# CheckingAccount and SavingsAccount inherit from Account
plt.arrow(0.73, 0.6, -0.02, -0.04, head_width=0.02, head_length=0.02, fc='black', ec='black')
plt.arrow(0.8, 0.6, -0.02, -0.04, head_width=0.02, head_length=0.02, fc='black', ec='black')
# AdminAccountView implements Observer
plt.arrow(0.755, 0.6, -0.03, -0.1, head_width=0.02, head_length=0.02, fc='black', ec='black')

# Set limits and hide axes
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.axis("off")
plt.title("UML 风格的包图 - 物体识别应用模块结构")
plt.show()
# Out:
# /var/folders/vg/tns4m8fd0d143728641f5s6w0000gn/T/ipykernel_70738/2217596293.py:9: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plt.gca().add_patch(plt.Rectangle((0.1, 0.7), 0.3, 0.2, fill=True, color='lightblue', edgecolor='black'))
# /var/folders/vg/tns4m8fd0d143728641f5s6w0000gn/T/ipykernel_70738/2217596293.py:13: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plt.gca().add_patch(plt.Rectangle((0.12, 0.75), 0.12, 0.05, fill=True, color='white', edgecolor='black'))
# /var/folders/vg/tns4m8fd0d143728641f5s6w0000gn/T/ipykernel_70738/2217596293.py:15: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   plt.gca().add_patch(plt.Rectangle((0.24, 0.75), 0.12, 0.05, fill=True, color='white', edgecolor='black'))
# ...
